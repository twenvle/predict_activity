# %%
import pandas as pd

df = pd.read_csv("20260621_gpr_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_gpr_yield_output.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("20260621_ols_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_ols_yield_output.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("20260621_pls_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_pls_yield_output.csv", index=False)

# %%
df = pd.read_csv("20260621_lasso_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_lasso_yield_output.csv", index=False)

df = pd.read_csv("20260621_ridge_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_ridge_yield_output.csv", index=False)

df = pd.read_csv("20260621_blr_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_blr_yield_output.csv", index=False)

df = pd.read_csv("20260621_svr_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_svr_yield_output.csv", index=False)

df = pd.read_csv("20260621_elasticnet_yield_output.csv")
df = df["smiles"]
df.to_csv("smiles/20260621_elasticnet_yield_output.csv", index=False)

# %%
a = list[1, "a"]
b = [1, "a"]
print(a)
print(b)
# Out:
# list[1, 'a']
# [1, 'a']

# %%
a = [1,2,3,4,5]
for b, i in enumerate(a):
    print(b, i)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4
# 4 5
