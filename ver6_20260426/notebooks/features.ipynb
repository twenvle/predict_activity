# %% [markdown]
# # Step2: 特徴量の取得
#
# このファイルは，前処理したファイルに対して，それぞれの化合物の特徴量を取得します．\
# まず，src内のpyファイルをインポートするために，sys.pathにsrcディレクトリを追加します．\
# そして，features.py内の関数を使用して，特徴量の取得を行います．\
# 具体的には，**RDKit・DFT計算などを活用**して，分子の特徴量を取得します．

# %%
import sys
from pathlib import Path
import pandas as pd

sys.path.append(str(Path().resolve().parent))

# %%
from src.features import get_data

df = pd.read_csv("../data/known/proceed/4th_20260503.csv")
df = get_data(df, name="4th_20260503")

# %%
from src.features import get_data

df = pd.read_csv("../data/known/proceed/3rd_20260523.csv")
df = get_data(df, name="3rd_20260523")

# %%
from src.features import get_data

df = pd.read_csv("../data/unknown/proceed/unknown.csv")
df = get_data(df, known=False, name="unknown_1-1500")
