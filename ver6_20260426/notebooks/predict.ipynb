# %% [markdown]
# ## Step4: 未知の化合物の予測
# Step 3はTSUBAMEを用いて計算を行います．
# そして，得られたモデルを用いて未知の化合物に対して予測を行います．

# %%
import sys
from pathlib import Path
import pandas as pd

sys.path.append(str(Path().resolve().parent))

# %%
from src.predict_all import predict

json_path = "../models/train_all_ver5_2_gpr_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_gpr_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="gpr",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator GaussianProcessRegressor from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
from src.predict_all import predict

json_path = "../models/train_all_ver5_2_ols_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_ols_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="ols",
    target="yield",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
from src.predict_all import predict

json_path = "../models/train_all_ver5_2_svr_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_svr_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="svr",
    target="yield",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator SVR from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
from src.predict_all import predict

json_path = "../models/train_all_ver5_2_pls_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_pls_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="pls",
    target="yield",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator PLSRegression from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# (               cas                                             smiles  \
#  0       66421-10-1  O=C(O)C1=CC=C(C=C1C(=O)O)C(=O)C2=CC=C(C(=C2)N(...
#  1       61837-56-7         O=C(O)C=1C=C(C(=O)OCC)C(=CC1C(=O)O)N(=O)=O
#  2      104825-37-8  O=C(O)C=1C=C(C(=CC1C(=O)O)CS(=O)(=O)C=2C=CC=CC...
#  3     1898181-04-8  O=C(O)C=1C=C(C(=CC1C(=O)O)CC(=O)C=2SC=CC2)N(=O)=O
#  4       39995-15-8  O=C(O)C1=CC=C(C=C1C(=O)O)C(=O)C2=CC=C(C=C2)N(=...
#  ...            ...                                                ...
# ...

# %%
from src.predict_all import predict

json_path = "../models/train_all_ver5_2_blr_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_blr_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="blr",
    target="yield",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator BayesianRidge from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
from src.predict_all import predict

json_path = "../models/train_all_ver5_2_lasso_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_lasso_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="lasso",
    target="yield",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator Lasso from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
json_path = "../models/train_all_ver5_2_ridge_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_ridge_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="ridge",
    target="yield",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator Ridge from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
json_path = "../models/train_all_ver5_2_elasticnet_3rd_20260523_yield_loo_summary.json"
json_path = Path(json_path)
pkl_path = "../models/train_all_ver5_2_elasticnet_3rd_20260523_yield_loo_final_estimator.pkl"
train_df = pd.read_csv("../data/known/features/3rd_20260523.csv")
candidate_df = pd.read_csv("../data/unknown/features/unknown.csv")

predict(
    summary_path=json_path,
    joblib_path=pkl_path,
    train_df=train_df,
    candidate_df=candidate_df,
    method="elasticnet",
    target="yield",
)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator ElasticNet from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...
