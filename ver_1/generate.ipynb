# %%
import phthalicacid as pa
smiles = "O=C(C1=C(C(O)=O)C=C(N=C(C=CC=C2)C2=N3)C3=C1)O"
cooh = pa.detect_phthalic_acid(smiles)
print(cooh)
# Out:
# [[1, 2, 0, 19, 27], [4, 3, 6, 5, 20]]

# %%
geom, fix = pa.generate_coord(smiles, cooh)
for g in geom:
    print(g)
# Out:
# 0 1
# O -0.6417 3.3728 0.9240
# C -0.1585 2.5174 0.2099
# C -0.7622 1.1743 0.0000
# C 0.0000 0.0000 0.0000
# C 1.4917 -0.0000 -0.0000
# O 2.0163 0.9413 0.7628
# O 2.1523 -0.8218 -0.6072
# C -0.6617 -1.2405 -0.0723
# C -2.0512 -1.3004 -0.1868
# N -2.6858 -2.5004 -0.2701
# C -4.0379 -2.5721 -0.3901
# C -4.6816 -3.8115 -0.4741
# C -6.0744 -3.8658 -0.5972
# C -6.8249 -2.6846 -0.6365
# C -6.1869 -1.4419 -0.5531
# C -4.7946 -1.3810 -0.4301
# N -4.1582 -0.1826 -0.3480
# C -2.8052 -0.1131 -0.2293
# C -2.1649 1.1235 -0.1375
# O 0.9358 2.7244 -0.5160
# H 3.0196 0.9301 0.7161
# H -0.0941 -2.1641 -0.0727
# H -4.1078 -4.7295 -0.4443
# H -6.5732 -4.8242 -0.6621
# H -7.9019 -2.7327 -0.7318
# H -6.7741 -0.5325 -0.5843
# H -2.7645 2.0265 -0.1408
# H 1.2862 3.6117 -0.3276
# O 4.6432 1.0130 0.7389
# H 4.9702 1.8236 0.3283
# H 5.0153 0.2937 0.2125
# O -2.0174 3.4108 2.8671
# H -1.5112 3.9468 3.4872
# H -1.5005 3.4249 2.0421
#
# 0 1
# O -0.5265 3.3294 1.0395
# C -0.1336 2.5317 0.2100
# ...

# %%
import phthalicacid as pa
smiles = "O=C1C2=C(C=C(C(O)=O)C(C(O)=O)=C2)C(C3=CC(Br)=CC=C31)=O"
cooh = pa.detect_phthalic_acid(smiles)
print(cooh)
# Out:
# [[6, 5, 8, 7, 24], [10, 9, 12, 11, 25]]

# %%
geom, fix = pa.generate_coord(smiles, cooh)
for g in geom:
    print(g)
# Out:
# 0 1
# O -2.0673 -3.6879 0.2321
# C -2.7428 -2.6227 0.2720
# C -2.0603 -1.3087 0.1854
# C -2.8138 -0.1215 0.2308
# C -2.1593 1.1172 0.1373
# C -0.7622 1.1743 0.0000
# C -0.1580 2.5174 -0.2088
# O 0.6854 2.5638 -1.2353
# O -0.4448 3.4983 0.4476
# C 0.0000 0.0000 0.0000
# C 1.4917 -0.0000 -0.0000
# O 2.0163 0.9413 0.7628
# O 2.1523 -0.8218 -0.6072
# C -0.6628 -1.2370 0.0715
# C -4.2898 -0.1857 0.3627
# C -4.9731 -1.4977 0.4487
# C -6.3727 -1.5700 0.5745
# C -7.0131 -2.8095 0.6553
# Br -8.9137 -2.8938 0.8259
# C -6.2642 -3.9867 0.6114
# C -4.8747 -3.9294 0.4867
# C -4.2171 -2.6884 0.4044
# O -4.9660 0.8790 0.4027
# H -2.7441 2.0296 0.1395
# H 1.0519 3.4612 -1.3128
# H 3.0196 0.9301 0.7161
# H -0.0808 -2.1512 0.0700
# H -6.9698 -0.6674 0.6102
# H -6.7583 -4.9478 0.6738
# H -4.3155 -4.8561 0.4549
# O 4.6432 1.0130 0.7389
# H 4.9702 1.8236 0.3283
# H 5.0153 0.2937 0.2125
# O -2.0174 3.4108 2.8671
# H -1.5112 3.9468 3.4872
# H -1.5005 3.4249 2.0421
#
# 0 1
# O -2.0673 -3.6879 -0.2321
# ...
