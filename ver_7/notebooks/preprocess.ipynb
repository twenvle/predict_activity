# %% [markdown]
# # Step1: 前処理
# このファイルは，機械学習モデルを作成するにあたり，必要な前処理を行うためのファイルです．\
# まず，src内のpyファイルをインポートするために，sys.pathにsrcディレクトリを追加します．\
# そして，preprocess.py内の関数を使用して，データの前処理を行います．\
# 具体的には，**イオンや塩を形成しているもの，金属を含むもの，同位体を含むもの**を除外します．

# %%
import sys
from pathlib import Path
import pandas as pd

sys.path.append(str(Path().resolve().parent))

# %%
from src.preprocess import screening

df = pd.read_excel("../data/known/raw/4th_20260503.xlsx")
df = screening(df, known=True, name="4th_20260503")

# %%
from src.preprocess import screening

df = pd.read_excel("../data/known/raw/3rd_20260523.xlsx")
df = screening(df, known=True, name="3rd_20260523")

# %%
from src.preprocess import screening

df = pd.read_csv("../data/unknown/raw/unknown.csv")
df = screening(df, known=False, name="unknown")

# %%
from src.preprocess import screening

df = pd.read_excel("../data/known/raw/5th_20260806.xlsx")
df = screening(df, known=True, name="5th_20260806")

# %%
from src.preprocess import screening, unknown_to_csv

unknown_to_csv("sulfonic_acid", limit=2000)
unknown_to_csv("carboxy_acid", limit=10000)
# Out:
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\kyoma\anaconda3\envs\predict_activity\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
from src.preprocess import screening

df = pd.read_csv("../data/unknown/raw/sulfonic_acid.csv")
df = screening(df, known=False, name="sulfonic_acid")

# %%
from src.preprocess import screening

df = pd.read_csv("../data/unknown/raw/carboxy_acid.csv")
df = screening(df, known=False, name="carboxy_acid")
