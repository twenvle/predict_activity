# %%
import sys
from pathlib import Path
import pandas as pd

sys.path.append(str(Path().resolve().parent))

# %%
from src.make_file import gjf_and_sh as gs

df = pd.read_csv("../data/known/proceed/5th_20260806.csv")
gs(df, dir_name="known")

# %%
from src.make_file import gjf_and_sh as gs

df = pd.read_csv("../data/unknown/proceed/sulfonic_acid.csv")
gs(df, file_range=[1, 1000])

# %%
len(df)
# Out:
# 1822

# %%
gs(df, file_range=[1001, 1822])
