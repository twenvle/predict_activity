# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\kyoma\Desktop\laboratory\ml\predict_activity\ver6_20260426\data\known\features\3rd_20260223_re.csv")
df2 = pd.read_csv(r"C:\Users\kyoma\Desktop\laboratory\ml\predict_activity\ver6_20260426\data\known\features\4th_20260503.csv")

# %%
common = df1.merge(df2, on='cas')
common["homo_ev"] = common["homo_ev_x"] == common["homo_ev_y"]
common["lumo_ev"] = common["lumo_ev_x"] == common["lumo_ev_y"]
common["gap_ev"] = common["gap_ev_x"] == common["gap_ev_y"]
common["dipole_moment_debye"] = common["dipole_moment_debye_x"] == common["dipole_moment_debye_y"]
common["o_nbo_charge"] = common["o_nbo_charge_x"] == common["o_nbo_charge_y"]
common["h_nbo_charge"] = common["h_nbo_charge_x"] == common["h_nbo_charge_y"]
common["omega"] = common["omega_x"] == common["omega_y"]
common["sasa"] = common["sasa_x"] == common["sasa_y"]
common["polar"] = common["polar_x"] == common["polar_y"]
common["molecular_volume_A3"] = common["molecular_volume_A3_x"] == common["molecular_volume_A3_y"]
common["3and6"] = common["3and6_x"] == common["3and6_y"]
common["4and5"] = common["4and5_x"] == common["4and5_y"]
common["hba"] = common["hba_x"] == common["hba_y"]
common["hbd"] = common["hbd_x"] == common["hbd_y"]
common["logp"] = common["logp_x"] == common["logp_y"]

# %%
print(common["hbd"])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# Name: hbd, dtype: bool

# %%
print(common[["cas","sasa_x","sasa_y"]])
# Out:
#            cas      sasa_x      sasa_y
# 0      88-99-3  186.158396  186.158396
# 1    2169-87-1  185.040914  185.040914
# 2      89-05-4  186.055071  186.055071
# 3     610-27-5  186.976035  186.976035
# 4     603-11-2  173.069686  173.069686
# 5           ee  187.968940  187.968940
# 6   27485-15-0  186.510756  186.510756
# 7    1885-13-8  186.949534  186.949534
# 8   14963-97-4  182.104257  182.104257
# 9         4-no  187.067814  187.067814
# 10        4-po  190.003021  190.003021
# 11        4-ne  189.540349  189.540349
# 12        3-ne  177.300650  177.300650
# 13        4-pe  190.178437  190.178437
# 14        4-nb  186.913767  186.913767
# 15  56962-08-4  188.940709  188.940709
# 16   2479-49-4  186.009055  186.009055
# 17  10351-75-4  184.678511  184.678511
# 18  18959-31-4  189.170731  189.170731
# 19  27563-65-1  178.445139  178.445139
# 20    652-03-9  180.324089  180.324089
# 21    528-44-9  186.091907  186.091907
# 22  10595-33-2  188.558197  188.558197
# ...

# %%
run_loo = False
run_repeated_kfold = True
run_kfold = True

cv_type = "loo_" if run_loo else ""
cv_type += "repeated_kfold_" if run_repeated_kfold else ""
cv_type += "kfold_" if run_kfold else ""

print(cv_type)
# Out:
# repeated_kfold_kfold_

# %%
print("done\n\n")
print(1)
# Out:
# done
#
#
# 1
