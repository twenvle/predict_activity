# %%
import graph.relative as rl
descriptors = [
    "yield", "homo_ev", "lumo_ev", "gap_ev", "omega", 
    "dipole_moment_debye", "molecular_volume_A3",
    "h_nbo_charge", "o_nbo_charge", "polar", "sasa", 
    "3and6", "4and5", "logp", "hbd", "hba",
    ]
rl.plot("2nd_20260205", descriptors=descriptors, x=16, y=6)

# %%
descriptors = ["dipole_moment_debye", "homo_ev", "lumo_ev", "3and6"]
rl.plot("1st_20260204", descriptors=descriptors, x=8, y=2)

# %%
import graph.relative as rl
descriptors = ["lumo_ev", "dipole_moment_debye", "sasa", "hbd"]
rl.plot("2nd_20260205", descriptors=descriptors, x=8, y=3)
