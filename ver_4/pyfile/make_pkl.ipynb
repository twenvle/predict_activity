# %%
import model.gauss_ver1 as g1

# %%
g1.make_model("1st_20260204")
# Out:
# 0.49224344003353493
# 1.776576635111934

# %%
g1.make_model("2nd_20260205")
# Out:
# 0.4497468015434487
# 1.833404110827643

# %%
g1.make_model("3rd_20260223")
# Out:
# 0.27214846851091246
# 2.294695980096467

# %%
import model.gauss_ver2 as g2

# %%
descriptors = ["lumo_ev", "dipole_moment_debye", "sasa", "hbd"]
g2.make_model(name="2nd_20260205", rename="2nd_20260211_4", descriptors=descriptors)
# Out:
# 0.7423611285410477
# 1.159665363727538

# %%
descriptors = ["lumo_ev", "sasa", "hbd"]
g2.make_model(name="2nd_20260205", rename="2nd_20260211_3", descriptors=descriptors)
# Out:
# c:\Users\kkyom\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 2 of parameter k1__k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# 0.6328253406334955
# 1.5253476704309599

# %%
descriptors = ["lumo_ev", "dipole_moment_debye", "sasa", "hbd"]
g2.make_model(name="3rd_20260223", rename="3rd_20260223_4", descriptors=descriptors)
# Out:
# 0.7180788725556637
# 1.3832352431944523

# %%
descriptors = ["lumo_ev", "sasa", "hbd"]
g2.make_model(name="3rd_20260223", rename="3rd_20260223_3", descriptors=descriptors)
# Out:
# c:\Users\kkyom\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 2 of parameter k1__k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\kkyom\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 2 of parameter k1__k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\kkyom\anaconda3\envs\predict_activity\Lib\site-packages\sklearn\gaussian_process\kernels.py:440: ConvergenceWarning: The optimal value found for dimension 2 of parameter k1__k2__length_scale is close to the specified lower bound 0.01. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...
