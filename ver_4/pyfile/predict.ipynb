# %%
import model.gauss_predict_ver2 as gp2

# %%
descriptors = ["lumo_ev", "dipole_moment_debye", "sasa", "hbd"]
gp2.make_csv("2nd_20260205", "2nd_20260211_4", descriptors=descriptors)

# %%
descriptors = ["dipole_moment_debye", "3and6", "lumo_ev", "homo_ev"]
gp2.make_csv("1st_20260204", "1st_20260204", descriptors=descriptors)
